# %% [markdown]
# #Object Detection for Security and Autonomous Systems
#
#
# ## **Objective**
# The goal of this project is to develop an **object detection model** using **Fastai** that can accurately classify images into **11 distinct categories**. This model will be useful for **security, surveillance, and autonomous systems**, where real-time object identification is crucial for decision-making.
#
# ## **Use Cases**
# - **Security & Surveillance**: Detecting humans, vehicles, and potential threats.
# - **Autonomous Vehicles**: Identifying obstacles like cars, trucks, and pedestrians.
# - **Aviation Safety**: Recognizing aircraft and airborne hazards like birds.
#
# ## **Categories for Detection**
# - **Human**
# - **Airplane**
# - **Automobile**
# - **Bird**
# - **Cat**
# - **Deer**
# - **Dog**
# - **Frog**
# - **Horse**
# - **Ship**
# - **Truck**

# %% [markdown]
# # Setting Up Necessary Things

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
bs = 32  # Batch size for training
version=2

# %%
# !pip install -Uqq fastai
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 95.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 80.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 52.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 60.5 MB/s eta 0:00:00

# %%
from fastai.vision.all import *

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls /content/drive/My\ Drive/
# Out:
# 'Object Detection for Security and Autonomous Systems'	 test

# %%
# %cd /content/drive/My Drive/DS PROJECTS/Object Detection for Security and Autonomous Systems
# Out:
# /content/drive/My Drive/DS PROJECTS/Object Detection for Security and Autonomous Systems

# %%
model_path = f'models/category_model_v{version}.pkl'

# %%
model = load_learner(model_path)

# %%
current_dir = os.getcwd()
current_dir
# Out:
# '/content/drive/MyDrive/DS PROJECTS/Object Detection for Security and Autonomous Systems'

# %%
img_path = os.path.join(current_dir, 'test_images')
img_path
# Out:
# '/content/drive/MyDrive/DS PROJECTS/Object Detection for Security and Autonomous Systems/test_images'

# %% [markdown]
# #Inference - 1
#
# **Target** : human

# %%
img = Image.open(os.path.join(img_path, '1.jpg'))
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x85>

# %%
model.predict(os.path.join(img_path, '1.jpg'))
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('human',
#  tensor(8),
#  tensor([3.7973e-06, 2.4100e-07, 1.3414e-07, 2.8646e-07, 8.2651e-09, 2.2247e-07,
#          1.4142e-08, 1.0576e-05, 9.9998e-01, 1.0123e-07, 7.4658e-07]))

# %% [markdown]
# #Inference - 2
#
# **Target**: airplane

# %%
img = Image.open(os.path.join(img_path, '2.jpg'))
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x86>

# %%
model.predict(os.path.join(img_path, '2.jpg'))
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('airplane',
#  tensor(0),
#  tensor([9.9981e-01, 2.4499e-07, 2.9748e-06, 9.9218e-09, 1.5758e-09, 3.6008e-06,
#          9.5103e-07, 2.0966e-06, 2.1879e-08, 1.6758e-04, 1.3094e-05]))

# %% [markdown]
# #Inference - 3
#
# **Target**: automobile

# %%
img = Image.open(os.path.join(img_path, '3.jpg'))
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x85>

# %%
model.predict(os.path.join(img_path, '3.jpg'))
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('automobile',
#  tensor(1),
#  tensor([7.7389e-07, 9.9998e-01, 1.0384e-07, 4.4461e-07, 1.5237e-06, 1.0236e-05,
#          4.6837e-06, 2.0177e-06, 1.7186e-06, 2.3215e-07, 1.5941e-06]))

# %% [markdown]
# #Inference - 4
#
# **Target**: bird

# %%
img = Image.open(os.path.join(img_path, '4.jpg'))
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x85>

# %%
model.predict(os.path.join(img_path, '4.jpg'))
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('bird',
#  tensor(2),
#  tensor([4.0192e-05, 2.9085e-07, 9.9991e-01, 1.7496e-05, 2.2458e-05, 7.7997e-08,
#          6.6390e-07, 1.5450e-06, 4.6322e-07, 2.5394e-07, 4.5582e-06]))

# %% [markdown]
# #Inference - 5
#
# **Target**: cat

# %%
img = Image.open(os.path.join(img_path, '5.jpg'))
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x85>

# %%
model.predict(os.path.join(img_path, '5.jpg'))
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('cat',
#  tensor(3),
#  tensor([4.0240e-07, 4.4617e-06, 1.1370e-04, 9.9901e-01, 2.0120e-05, 2.3425e-06,
#          6.0040e-07, 8.4348e-04, 4.0560e-07, 2.1374e-06, 8.1356e-07]))

# %% [markdown]
# #Inference - 6
#
# **Target**: frog

# %%
img = Image.open(os.path.join(img_path, '6.jpg'))
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x85>

# %%
model.predict(os.path.join(img_path, '6.jpg'))
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('frog',
#  tensor(6),
#  tensor([3.4680e-06, 6.8887e-05, 4.5827e-05, 3.2826e-04, 8.3788e-05, 3.7747e-04,
#          9.9894e-01, 8.1740e-05, 9.1179e-06, 1.1679e-05, 4.8824e-05]))

# %% [markdown]
# # Inference - 7
# **Target**: horse

# %%
img = Image.open(os.path.join(img_path, '7.jpg'))
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=92x128>

# %%
model.predict(os.path.join(img_path, '7.jpg'))
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('horse',
#  tensor(7),
#  tensor([2.3684e-07, 4.5172e-09, 3.3325e-08, 8.4146e-08, 2.2351e-08, 2.1676e-08,
#          9.0647e-09, 1.0000e+00, 9.1549e-07, 5.2211e-09, 1.5657e-06]))

# %% [markdown]
# # Inference - 8
# **Target**: truck

# %%
img = Image.open(os.path.join(img_path, '8.jpg'))
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x96>

# %%
model.predict(os.path.join(img_path, '8.jpg'))
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('truck',
#  tensor(10),
#  tensor([1.4189e-05, 7.6745e-06, 1.8477e-06, 2.8531e-07, 2.8748e-06, 6.3805e-07,
#          1.4537e-06, 8.4547e-07, 1.5193e-06, 6.5351e-05, 9.9990e-01]))
